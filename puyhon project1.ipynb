# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

import pandas as pd
import numpy as np
data = pd.read_csv('dataforprojectog.csv')
data
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  6-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  6-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  6-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  6-Oct     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  6-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  6-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  7-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  7-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data['Height']= np.random.uniform(150, 180, size = len(data))
data
data.drop_duplicates()
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  169.537513     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  166.206515     235
# 2     John Holland  Boston Celtics      30       SG   27  178.760980     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  172.756082     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.979882     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  160.196435     203
# 454      Raul Neto       Utah Jazz      25       PG   24  173.204888     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  176.303257     256
# 456    Jeff Withey       Utah Jazz      24        C   26  179.613818     231
# 457       Priyanka       Utah Jazz      34        C   25  158.591997     231
#
#                College     Salary
# ...

# %%
v = data['Salary'].mean()
v
# Out:
# 4833969.545861297

# %%
data['Salary'].fillna(v, inplace= True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  169.537513     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  166.206515     235
# 2     John Holland  Boston Celtics      30       SG   27  178.760980     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  172.756082     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.979882     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  160.196435     203
# 454      Raul Neto       Utah Jazz      25       PG   24  173.204888     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  176.303257     256
# 456    Jeff Withey       Utah Jazz      24        C   26  179.613818     231
# 457       Priyanka       Utah Jazz      34        C   25  158.591997     231
#
#                College        Salary
# ...

# %%
w = data['Weight'].mean()
data['Weight'].fillna(w, inplace= True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  169.537513     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  166.206515     235
# 2     John Holland  Boston Celtics      30       SG   27  178.760980     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  172.756082     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.979882     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  160.196435     203
# 454      Raul Neto       Utah Jazz      25       PG   24  173.204888     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  176.303257     256
# 456    Jeff Withey       Utah Jazz      24        C   26  179.613818     231
# 457       Priyanka       Utah Jazz      34        C   25  158.591997     231
#
#                College        Salary
# ...

# %%
A = data['Age'].mean()
data['Age'].fillna(A, inplace= True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  169.537513     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  166.206515     235
# 2     John Holland  Boston Celtics      30       SG   27  178.760980     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  172.756082     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.979882     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  160.196435     203
# 454      Raul Neto       Utah Jazz      25       PG   24  173.204888     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  176.303257     256
# 456    Jeff Withey       Utah Jazz      24        C   26  179.613818     231
# 457       Priyanka       Utah Jazz      34        C   25  158.591997     231
#
#                College        Salary
# ...

# %%
N = data['Number'].mean()
data['Number'].fillna(N, inplace= True)
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  169.537513     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  166.206515     235
# 2     John Holland  Boston Celtics      30       SG   27  178.760980     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  172.756082     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.979882     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  160.196435     203
# 454      Raul Neto       Utah Jazz      25       PG   24  173.204888     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  176.303257     256
# 456    Jeff Withey       Utah Jazz      24        C   26  179.613818     231
# 457       Priyanka       Utah Jazz      34        C   25  158.591997     231
#
#                College        Salary
# ...

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %%
data.to_csv('cleaneddata.csv', index=False)

# %%
data
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  169.537513     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  166.206515     235
# 2     John Holland  Boston Celtics      30       SG   27  178.760980     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  172.756082     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.979882     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  160.196435     203
# 454      Raul Neto       Utah Jazz      25       PG   24  173.204888     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  176.303257     256
# 456    Jeff Withey       Utah Jazz      24        C   26  179.613818     231
# 457       Priyanka       Utah Jazz      34        C   25  158.591997     231
#
#                College        Salary
# ...

# %%
#How many are there in each Team and the percentage splitting with respect to the total employees

# %%
team_n = data['Team'].value_counts()
team_n
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
team_persantage= (team_n / data['Team'].count()) * 100
team_persantage
# Out:
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# Philadelphia 76ers        3.275109
# ...

# %%
#Segregate the employees w.r.t different positions.

# %%
grouped_data = data.groupby('Position')

for position, group_data in grouped_data:
    print(position)
    print(group_data)
# Out:
# C
#                 Name                    Team  Number Position  Age  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25
# 10   Jared Sullinger          Boston Celtics       7        C   24
# 14      Tyler Zeller          Boston Celtics      44        C   26
# 23       Brook Lopez           Brooklyn Nets      11        C   28
# 27        Henry Sims           Brooklyn Nets      14        C   26
# ..               ...                     ...     ...      ...  ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26
# 447      Rudy Gobert               Utah Jazz      27        C   23
# 455     Tibor Pleiss               Utah Jazz      21        C   26
# 456      Jeff Withey               Utah Jazz      24        C   26
# 457         Priyanka               Utah Jazz      34        C   25
#
#          Height  Weight         College      Salary
# 7    166.818025     238         Gonzaga   2165160.0
# 10   176.120798     260      Ohio State   2569260.0
# ...

# %%
Find from which age group most of the employees belong to

# %%
age_group= pd.cut(data['Age'], bins=[20, 25, 30, 35, 40], labels=['20-24', '25-29', '30-34', '35-39'])

age_group
# Out:
# 0      20-24
# 1      20-24
# 2      25-29
# 3      20-24
# 4      25-29
#        ...
# 453    25-29
# 454    20-24
# 455    25-29
# 456    25-29
# 457    20-24
# Name: Age, Length: 458, dtype: category
# Categories (4, object): ['20-24' < '25-29' < '30-34' < '35-39']

# %%
count_age= age_group.value_counts()
count_age
# Out:
# 20-24    179
# 25-29    167
# 30-34     68
# 35-39     23
# Name: Age, dtype: int64

# %%
print("age group of most employers=", count_age.idxmax())
# Out:
# age group of most employers= 20-24

# %%
#Find out under which team and position, spending in terms of salary is high.

# %%
g_data = data.groupby(['Team', 'Position'])


salary_t_p = g_data['Salary'].sum()
salary_t_p.idxmax()


print("highest paid team by position", salary_t_p.idxmax())
# Out:
# highest paid team by position ('Los Angeles Lakers', 'SF')

# %%
#Find if there is any correlation between age and salary , represent it visually.

# %%
correlation = data['Age'].corr(data['Salary'])
print('Correlation coefficient between age and salary:', correlation)

plt.scatter(data['Age'], data['Salary'])
plt.xlabel('Age (years)')
plt.ylabel('Salary (USD)')
plt.title('Age vs Salary')
plt.show()
# Out:
# Correlation coefficient between age and salary: 0.21116954917686373
